# %%
from collections import Counter, defaultdict
import numpy as np
import pandas as pd
import re
import spacy
from tqdm import tqdm

# %%
df = pd.read_csv("/workspace/mica-text-robust-script-parser/results/seq_10.csv", index_col=None)

# %%
df.head()
# Out:
#            movie  start_line_no  end_line_no  \
# 0  44_inch_chest              1           10
# 1  44_inch_chest              2           11
# 2  44_inch_chest              3           12
# 3  44_inch_chest              4           13
# 4  44_inch_chest              5           14
#
#                                       line_1  \
# 0  out to wear ... whatever combination - it
# 1     works! - You look superb! ... And your
# 2  underw ear - immac ulate ! 100 % cot ton!
# 3      Dazzlin'!... Not like my pinky grey-y
# 4  things! Nah, you've just got it - good at
#
#                                       line_2  \
# 0     works! - You look superb! ... And your
# 1  underw ear - immac ulate ! 100 % cot ton!
# 2      Dazzlin'!... Not like my pinky grey-y
# 3  things! Nah, you've just got it - good at
# 4   everythin'! ... Me - on the other hand -
#
#                                       line_3  \
# 0  underw ear - immac ulate ! 100 % cot ton!
# ...

# %%
nlp = spacy.load("en_core_web_lg")

# %%
df.shape
# Out:
# (60048, 16)

# %%
doc = nlp("Machine learning (ML) methods, combined with large-scale electronic health databases, could enable a personalized approach to healthcare by improving patient-specific diagnosis, prognostic predictions, and treatment decisions.")

# %%
for token in doc:
    print(token, token.vector_norm, len(token.vector), token.tag_, token.is_upper)
# Out:
# Machine 6.7538133 300 NN False
# learning 6.542082 300 NN False
# ( 5.781955 300 -LRB- False
# ML 7.8142543 300 NNP True
# ) 5.489806 300 -RRB- False
# methods 6.7187476 300 NNS False
# , 5.094723 300 , False
# combined 5.189711 300 VBN False
# with 4.7708583 300 IN False
# large 5.9489884 300 JJ False
# - 5.6033444 300 HYPH False
# scale 6.433272 300 NN False
# electronic 7.126444 300 JJ False
# health 6.9867296 300 NN False
# databases 7.24441 300 NNS False
# , 5.094723 300 , False
# could 5.090426 300 MD False
# enable 5.8708034 300 VB False
# a 5.306696 300 DT False
# personalized 6.9729023 300 JJ False
# approach 5.8383727 300 NN False
# to 4.74484 300 IN False
# healthcare 6.9757137 300 NN False
# by 6.015159 300 IN False
# improving 6.1318207 300 VBG False
# patient 7.080826 300 NN False
# - 5.6033444 300 HYPH False
# specific 5.7073407 300 JJ False
# diagnosis 7.12941 300 NN False
# , 5.094723 300 , False
# prognostic 7.938558 300 JJ False
# ...

# %%
datadf = pd.read_csv("/workspace/mica-text-robust-script-parser/results/data.csv", index_col=None)
datadf.head()
# Out:
#            movie  line_no                                       text label  \
# 0  44_inch_chest        1  out to wear ... whatever combination - it     D
# 1  44_inch_chest        2     works! - You look superb! ... And your     D
# 2  44_inch_chest        3  underw ear - immac ulate ! 100 % cot ton!     D
# 3  44_inch_chest        4      Dazzlin'!... Not like my pinky grey-y     D
# 4  44_inch_chest        5  things! Nah, you've just got it - good at     D
#
#   error
# 0  NONE
# 1  NONE
# 2  NONE
# 3  NONE
# 4  NONE

# %%
def top_ngrams(lines, n=3, k=5):
    pass
# Out:
# top 5 transition keywords
# CUT 414
# TO: 360
# TO 162
# FADE 108
# BLACK 99

# %%
def word_vector_features(docs):
    d = len(docs[0][0].vector)
    feature = np.zeros(len(docs) * 20 * d)
    for i, doc in enumerate(docs):
        for j, token in enumerate(doc):
            feature[i * 20 * d + j * d: i * 20 * d + (j + 1) * d] = token.vector
    return feature

def pos_feature(docs):
    feature = np.full(len(docs) * 20, fill_value="PAD_POS", dtype=str)
    for i, doc in enumerate(docs):
        for j, token in enumerate(doc):
            feature[i * 20 + j] = token.tag_
    return feature

def length_feature(docs):
    return np.array([len(doc) for doc in docs])

def capitalization_feature(docs):
    return np.array([sum(token.is_upper for token in doc) for doc in docs])

def keyword_features(docs):
    keywords = ["INT", "EXT", "CUT", "FADE", "DISSOLVE"]
    contains_keyword = np.zeros(len(docs) * len(keywords), dtype=int)
    for i, doc in enumerate(docs):
        for j, keyword in enumerate(keywords):
            contains_keyword[i * len(keywords) + j] = int(any(token.lower == keyword.lower() for token in doc))
    return contains_keyword

# %%
doc_dict = {}

for (movie, error), mdf in df.groupby(["movie", "error"]):
    for _, row in mdf.iterrows():
        row_docs = []
        for i in range(10):
            line = row["line_{}".format(i + 1)]
            if line not in doc_dict:
                doc_dict[line] = nlp(line)
            row_docs.append(doc_dict[line])
